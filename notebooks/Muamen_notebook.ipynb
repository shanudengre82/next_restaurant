# %% [markdown]
# # using yelp api

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from next_restaurant.yelp import *

# %%
# add your api key
yelp_key = ''
# add search term, key and the start and end point 
call_yelp_api('food', yelp_key, 8,10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20249/1988195139.py in <module>
#       1 yelp_key = 'mLp16mnb4O8488f-vqLqMn3D5AF-P0_u07HUGOJ5ABod3ujzrSuhMMf_Si3piFGT4FmVWL3dpdAIwtkn0y8UaSEm1GjnSCG_N3IODzrPVC9dEtKqo6weSd6-UzkhYXYx'
#       2
# ----> 3 call_yelp_api('food', yelp_key, 8,10)
#
# ~/code/Muamenb/next_restaurant/next_restaurant/yelp.py in call_yelp_api(search_term, yelp_key, start_raw, end_raw)
#      25         index = int(coordinates_list.iloc[i]["index"])
#      26         pd.DataFrame(yelp_response).to_csv(f"yelp_berlin_coordinates_{index}.csv")
# ---> 27         results.extend(yelp_response['businesses'])
#      28     return results
#      29
#
# KeyError: 'businesses'
